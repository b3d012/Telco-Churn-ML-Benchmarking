# %% [markdown]
# # 01 Data Understanding
# This notebook introduces the raw Telco churn dataset and the modeling question.
#
# The goal is to understand the target, the available customer features, and the potential leakage risks before model training begins.

# %% [markdown]
# ## What this notebook does
# - Loads the raw dataset
# - Reviews the schema and basic structure
# - Frames the churn prediction task for benchmarking

# %%
from src.clean_and_prepare import load_raw_data

df = load_raw_data()
df.head()

# %% [markdown]
# The notebook stays lightweight so the focus remains on benchmarking, evaluation, and interpretation in the later steps.
