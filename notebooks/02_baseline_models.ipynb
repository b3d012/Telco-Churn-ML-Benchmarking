# %% [markdown]
# # 02 Baseline Models
# This notebook runs the first benchmark pass using straightforward default classifiers.
#
# The purpose is to establish a clear baseline before more advanced benchmarking, PCA analysis, and tuning.

# %% [markdown]
# ## Baseline focus
# - Logistic Regression
# - KNN
# - Decision Tree
# - Random Forest
# - Gradient Boosting

# %%
from src.baseline_models import main

main()

# %% [markdown]
# Metrics are written to `reports/baseline_model_metrics.csv` and the comparison chart is saved in `visuals/`.
