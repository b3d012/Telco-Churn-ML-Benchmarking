# %% [markdown]
# # 03 Model Benchmarking
# This notebook compares stronger models on the same leakage-safe split and preprocessing pipeline.
#
# The emphasis here is on fair model comparison and selection by ROC-AUC.

# %% [markdown]
# ## Comparison set
# - Balanced Logistic Regression
# - Random Forest
# - Gradient Boosting
# - KNN
# - XGBoost when available

# %%
from src.model_benchmarking import main

main()

# %% [markdown]
# The benchmark writes a metrics table, saves fitted pipelines, and stores the best model artifact in `models/`.
