# %% [markdown]
# # 04 PCA and Feature Analysis
# This notebook examines how much structure is visible after dimensionality reduction.
#
# PCA is used here for visualization and diagnostic insight, not as the only prediction strategy.

# %% [markdown]
# ## What to look for
# - Explained variance from PC1 and PC2
# - Overlap between churn classes in 2D
# - Whether PCA is useful for understanding the feature space

# %%
from src.pca_analysis import main

main()

# %% [markdown]
# The script writes the explained variance table and the PCA visuals to `reports/` and `visuals/`.
