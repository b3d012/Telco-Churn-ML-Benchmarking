# %% [markdown]
# # 05 XGBoost Interpretation
# This notebook highlights the tuned XGBoost model and the interpretation outputs.
#
# If XGBoost is unavailable in the environment, the script will exit cleanly and the rest of the project still runs.

# %% [markdown]
# ## Interpretation goals
# - Review the tuned model output
# - Inspect feature importance or permutation importance
# - Read the plain-English interpretation summary

# %%
from src.tune_xgboost import main
from src.explain_model import main as explain_main

main()
explain_main()

# %% [markdown]
# The tuning results, tuned model artifact, and explanation reports are stored in the project folders.
